# %% [markdown]
# # Stastic Notebook
# This is the notebook for our experiment’s data processing and statistics. It covers everything from handling `.fasta` files generated by our model to output statistical summaries — including **median/mean** results for **single seed** experiments and **median/mean** across **multiple seeds**. Please make sure to check and adjust the file paths accordingly.
# - Process `.fasta` files to `.txt` files.
# - Cauculate the single seed stastic data.
# - Cauculate the multiple seed stastic data.

# %%
import numpy as np
import os
import re
import glob
from pathlib import Path
from statistics import median
from typing import List

# %%
#####Process fasta files and generate the data txt files that we need#####
def parse_fasta_file(fasta_path):
    """
    Parse a single FASTA file to extract the input sequence length and metrics for 16 samples
    
    Returns:
    - input_length: Length of the input sequence
    - median_metrics: Median metrics for 16 samples {perplexity, recovery, edit_dist, sc_score}
    """
    try:
        with open(fasta_path, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # Split different sequence blocks
        sequences = content.strip().split('>')
        sequences = [seq.strip() for seq in sequences if seq.strip()]
        
        input_length = 0
        sample_metrics = []
        
        for seq_block in sequences:
            lines = seq_block.strip().split('\n')
            if not lines:
                continue
            
            header = lines[0]
            sequence_lines = lines[1:]
            
            # Process input sequence
            if 'input_sequence' in header:
                # Combine all sequence lines and calculate length
                sequence = ''.join(sequence_lines).replace(' ', '').replace('\n', '')
                input_length = len(sequence)
                print(f"  Input sequence length: {input_length}")
            
            # Process sample sequence
            elif 'sample=' in header:
                # Extract metrics using regular expressions
                perplexity_match = re.search(r'perplexity=([0-9.]+)', header)
                recovery_match = re.search(r'recovery=([0-9.]+)', header)
                edit_dist_match = re.search(r'edit_dist=([0-9.]+)', header)
                sc_score_match = re.search(r'sc_score=([0-9.]+)', header)
                
                if all([perplexity_match, recovery_match, edit_dist_match, sc_score_match]):
                    metrics = {
                        'perplexity': float(perplexity_match.group(1)),
                        'recovery': float(recovery_match.group(1)),
                        'edit_dist': float(edit_dist_match.group(1)),
                        'sc_score': float(sc_score_match.group(1))
                    }
                    sample_metrics.append(metrics)
        
        # Calculate medians
        if sample_metrics:
            median_metrics = {
                'perplexity': median(m['perplexity'] for m in sample_metrics),
                'recovery': median(m['recovery'] for m in sample_metrics),
                'edit_dist': median(m['edit_dist'] for m in sample_metrics),
                'sc_score': median(m['sc_score'] for m in sample_metrics)
            }
            print(f"  Found {len(sample_metrics)} samples")
            print(f"  Median metrics: perplexity={median_metrics['perplexity']:.4f}, recovery={median_metrics['recovery']:.4f}, edit_dist={median_metrics['edit_dist']:.4f}, sc_score={median_metrics['sc_score']:.4f}")
        else:
            print("  Warning: No valid sample metrics found")
            median_metrics = None
        
        return input_length, median_metrics
        
    except Exception as e:
        print(f"  Error: Exception occurred while processing file: {e}")
        return 0, None

def process_all_fasta_files(input_dir, output_file):
    """
    Process all FASTA files in the specified directory
    """
    print("=== FASTA File Processing Script ===")
    
    # Check input directory
    if not os.path.exists(input_dir):
        print(f"Error: Input directory does not exist: {input_dir}")
        return
    
    # Create output directory
    output_dir = os.path.dirname(output_file)
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)
        print(f"Output directory: {output_dir}")
    
    # Find all FASTA files
    fasta_pattern = os.path.join(input_dir, "*.fasta")
    fasta_files = glob.glob(fasta_pattern)
    
    if not fasta_files:
        print(f"Warning: No .fasta files found in {input_dir}")
        return
    
    print(f"Found {len(fasta_files)} FASTA files")
    
    # Store processing results
    results = []
    processed_count = 0
    failed_count = 0
    
    # Process each FASTA file
    for i, fasta_file in enumerate(sorted(fasta_files), 1):
        filename = os.path.basename(fasta_file)
        print(f"\n[{i}/{len(fasta_files)}] Processing file: {filename}")
        
        input_length, median_metrics = parse_fasta_file(fasta_file)
        
        if input_length > 0 and median_metrics is not None:
            # Format result
            result_line = f"{input_length} {median_metrics['perplexity']:.4f} {median_metrics['recovery']:.4f} {median_metrics['edit_dist']:.4f} {median_metrics['sc_score']:.4f}"
            results.append(result_line)
            processed_count += 1
            print(f"  ✓ Processed successfully")
        else:
            print(f"  ✗ Processing failed")
            failed_count += 1
    
    # Save results
    if results:
        try:
            with open(output_file, 'w', encoding='utf-8') as f:
                for result in results:
                    f.write(result + '\n')
            
            print(f"\n=== Processing Completed ===")
            print(f"Total files: {len(fasta_files)}")
            print(f"Successfully processed: {processed_count}")
            print(f"Failed: {failed_count}")
            print(f"Results saved to: {output_file}")
            
            # Show preview of first few lines
            print(f"\nResults preview (first 5 lines):")
            for i, result in enumerate(results[:5]):
                print(f"  {result}")
            if len(results) > 5:
                print(f"  ... (total {len(results)} lines)")
                
        except Exception as e:
            print(f"Error saving file: {e}")
    else:
        print("No successfully processed data, unable to generate output file")

def validate_output_format(output_file):
    """
    Validate the format of the output file
    """
    if not os.path.exists(output_file):
        print("Output file does not exist")
        return
    
    print(f"\n=== Validate Output Format ===")
    try:
        with open(output_file, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        
        print(f"Total lines: {len(lines)}")
        
        for i, line in enumerate(lines[:3], 1):  # Check first 3 lines
            parts = line.strip().split()
            if len(parts) == 5:
                length = int(parts[0])
                perplexity = float(parts[1])
                recovery = float(parts[2])
                edit_dist = float(parts[3])
                sc_score = float(parts[4])
                print(f"Line {i}: length={length}, perplexity={perplexity}, recovery={recovery}, edit_dist={edit_dist}, sc_score={sc_score}")
            else:
                print(f"Line {i} format error: {line.strip()}")
    
    except Exception as e:
        print(f"Error during validation: {e}")

def main():
    """
    Main function
    """
    # Set input and output paths
    input_directory = "./testfasta/gr_1_seed4"
    output_filepath = "./data/gr_1_seed4.txt"

    # Process all FASTA files
    process_all_fasta_files(input_directory, output_filepath)
    
    # Validate output format
    validate_output_format(output_filepath)

if __name__ == "__main__":
    main()
# Out:
# === FASTA File Processing Script ===
# Output directory: ./data
# Found 612 FASTA files
#
# [1/612] Processing file: 1EFW_1_C.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.2711, recovery=0.6667, edit_dist=21.0000, sc_score=0.8121
#   ✓ Processed successfully
#
# [2/612] Processing file: 1EFW_1_D.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.2607, recovery=0.6429, edit_dist=22.5000, sc_score=0.7189
#   ✓ Processed successfully
#
# [3/612] Processing file: 1EHT_3_A.fasta
#   Input sequence length: 33
#   Found 10 samples
#   Median metrics: perplexity=1.3628, recovery=0.6406, edit_dist=12.5000, sc_score=0.5989
#   ✓ Processed successfully
#
# [4/612] Processing file: 1EHZ_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2371, recovery=0.7419, edit_dist=15.0000, sc_score=0.6084
#   ✓ Processed successfully
#
# [5/612] Processing file: 1EVV_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2560, recovery=0.7581, edit_dist=13.0000, sc_score=0.4957
#   ✓ Processed successfully
#
# [6/612] Processing file: 1FCW_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1926, recovery=0.7823, edit_dist=13.5000, sc_score=0.3621
#   ✓ Processed successfully
#
# [7/612] Processing file: 1FCW_1_B.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1926, recovery=0.7823, edit_dist=13.5000, sc_score=0.3621
#   ✓ Processed successfully
#
# [8/612] Processing file: 1FCW_1_C.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1926, recovery=0.7823, edit_dist=13.5000, sc_score=0.3621
#   ✓ Processed successfully
#
# [9/612] Processing file: 1FCW_1_D.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1927, recovery=0.7823, edit_dist=13.5000, sc_score=0.3621
#   ✓ Processed successfully
#
# [10/612] Processing file: 1FCW_1_E.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1925, recovery=0.7823, edit_dist=13.5000, sc_score=0.3621
#   ✓ Processed successfully
#
# [11/612] Processing file: 1HMH_1_A.fasta
#   Input sequence length: 34
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [12/612] Processing file: 1HMH_1_C.fasta
#   Input sequence length: 34
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [13/612] Processing file: 1HMH_1_E.fasta
#   Input sequence length: 34
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [14/612] Processing file: 1J7T_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.3308, recovery=0.7381, edit_dist=10.5000, sc_score=0.8799
#   ✓ Processed successfully
#
# [15/612] Processing file: 1JGO_1_B.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2794, recovery=0.7419, edit_dist=15.0000, sc_score=0.5653
#   ✓ Processed successfully
#
# [16/612] Processing file: 1JGO_1_C.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2501, recovery=0.7097, edit_dist=17.0000, sc_score=0.5557
#   ✓ Processed successfully
#
# [17/612] Processing file: 1JGP_1_B.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2794, recovery=0.7419, edit_dist=15.0000, sc_score=0.5653
#   ✓ Processed successfully
#
# [18/612] Processing file: 1JGP_1_C.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2501, recovery=0.7097, edit_dist=17.0000, sc_score=0.5557
#   ✓ Processed successfully
#
# [19/612] Processing file: 1JGQ_1_B.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2794, recovery=0.7419, edit_dist=15.0000, sc_score=0.5653
#   ✓ Processed successfully
#
# [20/612] Processing file: 1JGQ_1_C.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2501, recovery=0.7097, edit_dist=17.0000, sc_score=0.5557
#   ✓ Processed successfully
#
# [21/612] Processing file: 1LC4_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2309, recovery=0.7500, edit_dist=10.0000, sc_score=0.7873
#   ✓ Processed successfully
#
# [22/612] Processing file: 1MME_1_B-A.fasta
#   Input sequence length: 41
#   Found 1 samples
#   Median metrics: perplexity=1.6848, recovery=0.4872, edit_dist=20.0000, sc_score=0.1036
#   ✓ Processed successfully
#
# [23/612] Processing file: 1MME_1_D-C.fasta
#   Input sequence length: 41
#   Found 4 samples
#   Median metrics: perplexity=1.4750, recovery=0.3589, edit_dist=21.5000, sc_score=0.1985
#   ✓ Processed successfully
#
# [24/612] Processing file: 1MWL_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1649, recovery=0.8095, edit_dist=6.0000, sc_score=0.8799
#   ✓ Processed successfully
#
# [25/612] Processing file: 1NLC_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.3550, recovery=0.5909, edit_dist=19.0000, sc_score=0.9205
#   ✓ Processed successfully
#
# [26/612] Processing file: 1O15_1_A.fasta
#   Input sequence length: 33
#   Found 16 samples
#   Median metrics: perplexity=1.1990, recovery=0.8125, edit_dist=6.5000, sc_score=0.8552
#   ✓ Processed successfully
#
# [27/612] Processing file: 1O3Z_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.3525, recovery=0.5909, edit_dist=18.5000, sc_score=0.8939
#   ✓ Processed successfully
#
# [28/612] Processing file: 1O9M_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2803, recovery=0.7000, edit_dist=12.5000, sc_score=0.7546
#   ✓ Processed successfully
#
# [29/612] Processing file: 1RRR_1_A-B.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.8958, recovery=0.2778, edit_dist=12.0000, sc_score=0.9324
#   ✓ Processed successfully
#
# [30/612] Processing file: 1SZ1_1_E.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2593, recovery=0.7705, edit_dist=15.0000, sc_score=0.2406
#   ✓ Processed successfully
#
# [31/612] Processing file: 1SZ1_1_F.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2652, recovery=0.7541, edit_dist=15.0000, sc_score=0.3274
#   ✓ Processed successfully
#
# [32/612] Processing file: 1TFY_1_G-J.fasta
#   Input sequence length: 19
#   Found 16 samples
#   Median metrics: perplexity=2.0873, recovery=0.2941, edit_dist=10.0000, sc_score=0.9225
#   ✓ Processed successfully
#
# [33/612] Processing file: 1TN1_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2146, recovery=0.7097, edit_dist=17.0000, sc_score=0.5158
#   ✓ Processed successfully
#
# [34/612] Processing file: 1TN2_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2146, recovery=0.7097, edit_dist=17.0000, sc_score=0.5158
#   ✓ Processed successfully
#
# [35/612] Processing file: 1TRA_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2565, recovery=0.7258, edit_dist=17.0000, sc_score=0.5909
#   ✓ Processed successfully
#
# [36/612] Processing file: 1TTT_1_D.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2182, recovery=0.6935, edit_dist=19.0000, sc_score=0.3535
#   ✓ Processed successfully
#
# [37/612] Processing file: 1TTT_1_E.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.3505, recovery=0.6774, edit_dist=19.5000, sc_score=0.3626
#   ✓ Processed successfully
#
# [38/612] Processing file: 1TTT_1_F.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2719, recovery=0.7097, edit_dist=18.0000, sc_score=0.3736
#   ✓ Processed successfully
#
# [39/612] Processing file: 1WVD_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.4192, recovery=0.5682, edit_dist=19.5000, sc_score=0.8939
#   ✓ Processed successfully
#
# [40/612] Processing file: 1WZ2_1_C.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.2462, recovery=0.6250, edit_dist=30.0000, sc_score=0.6419
#   ✓ Processed successfully
#
# [41/612] Processing file: 1WZ2_1_D.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.2767, recovery=0.6193, edit_dist=31.0000, sc_score=0.6278
#   ✓ Processed successfully
#
# [42/612] Processing file: 1XJR_1_A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.3982, recovery=0.4130, edit_dist=23.5000, sc_score=0.6425
#   ✓ Processed successfully
#
# [43/612] Processing file: 1XMQ_1_X-W.fasta
#   Input sequence length: 14
#   Found 13 samples
#   Median metrics: perplexity=1.9840, recovery=0.3333, edit_dist=8.0000, sc_score=0.4789
#   ✓ Processed successfully
#
# [44/612] Processing file: 1XPF_1_A-B.fasta
#   Input sequence length: 46
#   Found 9 samples
#   Median metrics: perplexity=1.2882, recovery=0.6136, edit_dist=18.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [45/612] Processing file: 1Y6S_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.4519, recovery=0.4545, edit_dist=21.0000, sc_score=0.8939
#   ✓ Processed successfully
#
# [46/612] Processing file: 1Y6T_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.3924, recovery=0.5909, edit_dist=19.0000, sc_score=0.8939
#   ✓ Processed successfully
#
# [47/612] Processing file: 1Y73_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.4196, recovery=0.5227, edit_dist=20.0000, sc_score=0.8939
#   ✓ Processed successfully
#
# [48/612] Processing file: 1Y95_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.5146, recovery=0.5455, edit_dist=20.0000, sc_score=0.8939
#   ✓ Processed successfully
#
# [49/612] Processing file: 1Y99_1_A-B.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.4205, recovery=0.5227, edit_dist=21.0000, sc_score=0.9205
#   ✓ Processed successfully
#
# [50/612] Processing file: 1YFG_1_A.fasta
#   Input sequence length: 64
#   Found 16 samples
#   Median metrics: perplexity=1.2475, recovery=0.5625, edit_dist=23.0000, sc_score=0.8076
#   ✓ Processed successfully
#
# [51/612] Processing file: 1YRJ_1_A-B.fasta
#   Input sequence length: 45
#   Found 16 samples
#   Median metrics: perplexity=1.2350, recovery=0.7326, edit_dist=13.0000, sc_score=0.8475
#   ✓ Processed successfully
#
# [52/612] Processing file: 299D_1_B-A.fasta
#   Input sequence length: 41
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [53/612] Processing file: 2B8S_1_A-B.fasta
#   Input sequence length: 46
#   Found 10 samples
#   Median metrics: perplexity=1.2428, recovery=0.6818, edit_dist=15.5000, sc_score=0.9603
#   ✓ Processed successfully
#
# [54/612] Processing file: 2BE0_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1545, recovery=0.8095, edit_dist=8.0000, sc_score=0.7252
#   ✓ Processed successfully
#
# [55/612] Processing file: 2BEE_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1408, recovery=0.8095, edit_dist=8.0000, sc_score=0.7252
#   ✓ Processed successfully
#
# [56/612] Processing file: 2DR5_1_B.fasta
#   Input sequence length: 32
#   Found 16 samples
#   Median metrics: perplexity=1.3228, recovery=0.7344, edit_dist=8.0000, sc_score=0.7957
#   ✓ Processed successfully
#
# [57/612] Processing file: 2ESI_1_A-B.fasta
#   Input sequence length: 44
#   Found 15 samples
#   Median metrics: perplexity=1.3704, recovery=0.6905, edit_dist=14.0000, sc_score=0.8725
#   ✓ Processed successfully
#
# [58/612] Processing file: 2ESJ_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2161, recovery=0.6905, edit_dist=12.0000, sc_score=0.9417
#   ✓ Processed successfully
#
# [59/612] Processing file: 2ET3_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2072, recovery=0.9048, edit_dist=4.0000, sc_score=0.8399
#   ✓ Processed successfully
#
# [60/612] Processing file: 2ET4_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2496, recovery=0.7143, edit_dist=12.0000, sc_score=0.9417
#   ✓ Processed successfully
#
# [61/612] Processing file: 2ET5_1_A-B.fasta
#   Input sequence length: 42
#   Found 15 samples
#   Median metrics: perplexity=1.2725, recovery=0.6667, edit_dist=14.0000, sc_score=0.9417
#   ✓ Processed successfully
#
# [62/612] Processing file: 2ET8_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2748, recovery=0.7619, edit_dist=10.0000, sc_score=0.8399
#   ✓ Processed successfully
#
# [63/612] Processing file: 2F4S_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2376, recovery=0.6190, edit_dist=16.0000, sc_score=0.8474
#   ✓ Processed successfully
#
# [64/612] Processing file: 2F4U_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.3639, recovery=0.7250, edit_dist=12.0000, sc_score=0.8569
#   ✓ Processed successfully
#
# [65/612] Processing file: 2G5K_1_A-B.fasta
#   Input sequence length: 44
#   Found 16 samples
#   Median metrics: perplexity=1.2020, recovery=0.6250, edit_dist=16.5000, sc_score=0.5610
#   ✓ Processed successfully
#
# [66/612] Processing file: 2O3X_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2502, recovery=0.8333, edit_dist=7.0000, sc_score=0.7605
#   ✓ Processed successfully
#
# [67/612] Processing file: 2OE5_1_B-A.fasta
#   Input sequence length: 33
#   Found 3 samples
#   Median metrics: perplexity=1.6087, recovery=0.4839, edit_dist=14.0000, sc_score=0.3872
#   ✓ Processed successfully
#
# [68/612] Processing file: 2OE6_1_B-A.fasta
#   Input sequence length: 33
#   Found 4 samples
#   Median metrics: perplexity=1.5266, recovery=0.4839, edit_dist=15.5000, sc_score=0.3688
#   ✓ Processed successfully
#
# [69/612] Processing file: 2OE8_1_B-A.fasta
#   Input sequence length: 33
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [70/612] Processing file: 2OEU_1_A.fasta
#   Input sequence length: 42
#   Found 15 samples
#   Median metrics: perplexity=1.3493, recovery=0.5000, edit_dist=18.0000, sc_score=0.5305
#   ✓ Processed successfully
#
# [71/612] Processing file: 2PWT_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1682, recovery=0.6905, edit_dist=13.0000, sc_score=0.9113
#   ✓ Processed successfully
#
# [72/612] Processing file: 2R92_1_T-P.fasta
#   Input sequence length: 19
#   Found 16 samples
#   Median metrics: perplexity=1.9238, recovery=0.4706, edit_dist=10.0000, sc_score=0.8597
#   ✓ Processed successfully
#
# [73/612] Processing file: 2ZZM_1_B.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2298, recovery=0.6667, edit_dist=27.0000, sc_score=0.4514
#   ✓ Processed successfully
#
# [74/612] Processing file: 300D_1_B-A.fasta
#   Input sequence length: 41
#   Found 1 samples
#   Median metrics: perplexity=1.6539, recovery=0.4872, edit_dist=21.0000, sc_score=0.1277
#   ✓ Processed successfully
#
# [75/612] Processing file: 301D_1_B-A.fasta
#   Input sequence length: 41
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [76/612] Processing file: 315D_1_A-B.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.6577, recovery=0.5000, edit_dist=8.0000, sc_score=0.2513
#   ✓ Processed successfully
#
# [77/612] Processing file: 357D_1_C-B-A.fasta
#   Input sequence length: 60
#   Found 16 samples
#   Median metrics: perplexity=1.2922, recovery=0.6316, edit_dist=22.0000, sc_score=0.7771
#   ✓ Processed successfully
#
# [78/612] Processing file: 359D_1_B-A.fasta
#   Input sequence length: 41
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [79/612] Processing file: 364D_1_C-B-A.fasta
#   Input sequence length: 60
#   Found 14 samples
#   Median metrics: perplexity=1.4582, recovery=0.5517, edit_dist=26.0000, sc_score=0.7735
#   ✓ Processed successfully
#
# [80/612] Processing file: 379D_1_B-A.fasta
#   Input sequence length: 41
#   Found 2 samples
#   Median metrics: perplexity=1.6210, recovery=0.4211, edit_dist=19.0000, sc_score=0.1219
#   ✓ Processed successfully
#
# [81/612] Processing file: 3A3A_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3028, recovery=0.6047, edit_dist=32.0000, sc_score=0.5769
#   ✓ Processed successfully
#
# [82/612] Processing file: 3ADB_1_C.fasta
#   Input sequence length: 92
#   Found 16 samples
#   Median metrics: perplexity=1.3809, recovery=0.6141, edit_dist=33.0000, sc_score=0.6543
#   ✓ Processed successfully
#
# [83/612] Processing file: 3ADB_1_D.fasta
#   Input sequence length: 92
#   Found 16 samples
#   Median metrics: perplexity=1.2638, recovery=0.5000, edit_dist=36.5000, sc_score=0.8196
#   ✓ Processed successfully
#
# [84/612] Processing file: 3ADC_1_C.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.3053, recovery=0.5966, edit_dist=31.5000, sc_score=0.9558
#   ✓ Processed successfully
#
# [85/612] Processing file: 3ADC_1_D.fasta
#   Input sequence length: 92
#   Found 16 samples
#   Median metrics: perplexity=1.3748, recovery=0.5435, edit_dist=33.0000, sc_score=0.9278
#   ✓ Processed successfully
#
# [86/612] Processing file: 3ADD_1_C.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.2797, recovery=0.5966, edit_dist=33.5000, sc_score=0.9699
#   ✓ Processed successfully
#
# [87/612] Processing file: 3ADD_1_D.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.3567, recovery=0.5113, edit_dist=35.5000, sc_score=0.9633
#   ✓ Processed successfully
#
# [88/612] Processing file: 3AM1_1_B.fasta
#   Input sequence length: 81
#   Found 16 samples
#   Median metrics: perplexity=1.3148, recovery=0.4568, edit_dist=40.0000, sc_score=0.9369
#   ✓ Processed successfully
#
# [89/612] Processing file: 3BSN_1_T-P.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.7395, recovery=0.3928, edit_dist=8.5000, sc_score=0.9079
#   ✓ Processed successfully
#
# [90/612] Processing file: 3BSO_1_T-P.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.7014, recovery=0.5000, edit_dist=7.0000, sc_score=0.9220
#   ✓ Processed successfully
#
# [91/612] Processing file: 3CUL_1_C.fasta
#   Input sequence length: 91
#   Found 16 samples
#   Median metrics: perplexity=1.2520, recovery=0.5834, edit_dist=37.0000, sc_score=0.6320
#   ✓ Processed successfully
#
# [92/612] Processing file: 3CUL_1_D.fasta
#   Input sequence length: 92
#   Found 16 samples
#   Median metrics: perplexity=1.3009, recovery=0.5109, edit_dist=38.0000, sc_score=0.8392
#   ✓ Processed successfully
#
# [93/612] Processing file: 3CUN_1_C.fasta
#   Input sequence length: 91
#   Found 16 samples
#   Median metrics: perplexity=1.2236, recovery=0.5440, edit_dist=40.0000, sc_score=0.9044
#   ✓ Processed successfully
#
# [94/612] Processing file: 3CUN_1_D.fasta
#   Input sequence length: 91
#   Found 16 samples
#   Median metrics: perplexity=1.2693, recovery=0.5769, edit_dist=35.5000, sc_score=0.8311
#   ✓ Processed successfully
#
# [95/612] Processing file: 3EGZ_1_B.fasta
#   Input sequence length: 65
#   Found 16 samples
#   Median metrics: perplexity=1.2916, recovery=0.6328, edit_dist=24.0000, sc_score=0.9251
#   ✓ Processed successfully
#
# [96/612] Processing file: 3H5X_1_T-P.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.8601, recovery=0.5000, edit_dist=7.5000, sc_score=0.9220
#   ✓ Processed successfully
#
# [97/612] Processing file: 3H5Y_1_T-P.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.8449, recovery=0.5312, edit_dist=7.0000, sc_score=0.9220
#   ✓ Processed successfully
#
# [98/612] Processing file: 3HL2_1_E.fasta
#   Input sequence length: 82
#   Found 16 samples
#   Median metrics: perplexity=1.2710, recovery=0.5305, edit_dist=34.0000, sc_score=0.6828
#   ✓ Processed successfully
#
# [99/612] Processing file: 3J9M_1_AA.fasta
#   Input sequence length: 923
#   Found 16 samples
#   Median metrics: perplexity=1.2459, recovery=0.6240, edit_dist=330.0000, sc_score=0.4052
#   ✓ Processed successfully
#
# [100/612] Processing file: 3J9Y_1_v.fasta
#   Input sequence length: 73
#   Found 16 samples
#   Median metrics: perplexity=1.1201, recovery=0.9246, edit_dist=5.5000, sc_score=0.4637
#   ✓ Processed successfully
#
# [101/612] Processing file: 3JB7_1_t-m.fasta
#   Input sequence length: 11
#   Found 15 samples
#   Median metrics: perplexity=1.7050, recovery=0.2727, edit_dist=8.0000, sc_score=0.7610
#   ✓ Processed successfully
#
# [102/612] Processing file: 3JCJ_1_v.fasta
#   Input sequence length: 73
#   Found 13 samples
#   Median metrics: perplexity=1.2906, recovery=0.6575, edit_dist=23.0000, sc_score=0.2323
#   ✓ Processed successfully
#
# [103/612] Processing file: 3JCN_1_v.fasta
#   Input sequence length: 73
#   Found 16 samples
#   Median metrics: perplexity=1.2846, recovery=0.6438, edit_dist=24.5000, sc_score=0.1889
#   ✓ Processed successfully
#
# [104/612] Processing file: 3JCS_1_3.fasta
#   Input sequence length: 184
#   Found 16 samples
#   Median metrics: perplexity=1.6131, recovery=0.3804, edit_dist=99.5000, sc_score=0.4130
#   ✓ Processed successfully
#
# [105/612] Processing file: 3LRR_1_C-D.fasta
#   Input sequence length: 22
#   Found 16 samples
#   Median metrics: perplexity=1.9353, recovery=0.1818, edit_dist=15.0000, sc_score=0.9466
#   ✓ Processed successfully
#
# [106/612] Processing file: 3MQK_1_D-E.fasta
#   Input sequence length: 22
#   Found 16 samples
#   Median metrics: perplexity=1.6240, recovery=0.1818, edit_dist=13.0000, sc_score=0.5197
#   ✓ Processed successfully
#
# [107/612] Processing file: 3NCU_1_C-D.fasta
#   Input sequence length: 22
#   Found 16 samples
#   Median metrics: perplexity=1.8687, recovery=0.3409, edit_dist=11.5000, sc_score=0.9466
#   ✓ Processed successfully
#
# [108/612] Processing file: 3OG8_1_C-D.fasta
#   Input sequence length: 28
#   Found 16 samples
#   Median metrics: perplexity=1.7409, recovery=0.5000, edit_dist=11.0000, sc_score=0.9560
#   ✓ Processed successfully
#
# [109/612] Processing file: 3OL6_1_B-F-C-G-D-H.fasta
#   Input sequence length: 70
#   Found 13 samples
#   Median metrics: perplexity=1.6110, recovery=0.4242, edit_dist=34.0000, sc_score=0.8131
#   ✓ Processed successfully
#
# [110/612] Processing file: 3OL6_1_J-N-K-O-L-P.fasta
#   Input sequence length: 74
#   Found 15 samples
#   Median metrics: perplexity=1.5005, recovery=0.4143, edit_dist=37.0000, sc_score=0.9657
#   ✓ Processed successfully
#
# [111/612] Processing file: 3OL7_1_B-F-C-G-D-H.fasta
#   Input sequence length: 72
#   Found 15 samples
#   Median metrics: perplexity=1.5711, recovery=0.3529, edit_dist=39.0000, sc_score=0.8576
#   ✓ Processed successfully
#
# [112/612] Processing file: 3OL7_1_J-N-K-O-L-P.fasta
#   Input sequence length: 70
#   Found 15 samples
#   Median metrics: perplexity=1.5877, recovery=0.3824, edit_dist=36.0000, sc_score=0.8882
#   ✓ Processed successfully
#
# [113/612] Processing file: 3OL8_1_B-F-C-G-D-H.fasta
#   Input sequence length: 70
#   Found 16 samples
#   Median metrics: perplexity=1.7534, recovery=0.3939, edit_dist=36.5000, sc_score=0.8971
#   ✓ Processed successfully
#
# [114/612] Processing file: 3OL8_1_J-N-K-O-L-P.fasta
#   Input sequence length: 72
#   Found 15 samples
#   Median metrics: perplexity=1.6240, recovery=0.3676, edit_dist=36.0000, sc_score=0.9061
#   ✓ Processed successfully
#
# [115/612] Processing file: 3OL9_1_B-F-C-G-D-H.fasta
#   Input sequence length: 70
#   Found 13 samples
#   Median metrics: perplexity=1.6790, recovery=0.4242, edit_dist=34.0000, sc_score=0.8131
#   ✓ Processed successfully
#
# [116/612] Processing file: 3OL9_1_J-N-K-O-L-P.fasta
#   Input sequence length: 74
#   Found 15 samples
#   Median metrics: perplexity=1.5135, recovery=0.4000, edit_dist=38.0000, sc_score=0.9657
#   ✓ Processed successfully
#
# [117/612] Processing file: 3OLB_1_B-F-C-G-D-H.fasta
#   Input sequence length: 70
#   Found 15 samples
#   Median metrics: perplexity=1.5607, recovery=0.4848, edit_dist=32.0000, sc_score=0.8131
#   ✓ Processed successfully
#
# [118/612] Processing file: 3OLB_1_J-N-K-O-L-P.fasta
#   Input sequence length: 74
#   Found 16 samples
#   Median metrics: perplexity=1.5623, recovery=0.4357, edit_dist=37.0000, sc_score=0.9657
#   ✓ Processed successfully
#
# [119/612] Processing file: 3OWI_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3563, recovery=0.6279, edit_dist=30.0000, sc_score=0.6779
#   ✓ Processed successfully
#
# [120/612] Processing file: 3OWI_1_B.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.4116, recovery=0.5000, edit_dist=39.0000, sc_score=0.5857
#   ✓ Processed successfully
#
# [121/612] Processing file: 3OWW_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3467, recovery=0.5814, edit_dist=33.0000, sc_score=0.6274
#   ✓ Processed successfully
#
# [122/612] Processing file: 3OWW_1_B.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3528, recovery=0.4651, edit_dist=40.5000, sc_score=0.7093
#   ✓ Processed successfully
#
# [123/612] Processing file: 3OWZ_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3651, recovery=0.5523, edit_dist=34.5000, sc_score=0.7238
#   ✓ Processed successfully
#
# [124/612] Processing file: 3OWZ_1_B.fasta
#   Input sequence length: 82
#   Found 16 samples
#   Median metrics: perplexity=1.3489, recovery=0.5000, edit_dist=38.0000, sc_score=0.6905
#   ✓ Processed successfully
#
# [125/612] Processing file: 3OX0_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3436, recovery=0.5639, edit_dist=34.0000, sc_score=0.7637
#   ✓ Processed successfully
#
# [126/612] Processing file: 3OX0_1_B.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.3364, recovery=0.5344, edit_dist=38.0000, sc_score=0.8249
#   ✓ Processed successfully
#
# [127/612] Processing file: 3OXB_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3252, recovery=0.6279, edit_dist=31.0000, sc_score=0.6779
#   ✓ Processed successfully
#
# [128/612] Processing file: 3OXB_1_B.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3233, recovery=0.4651, edit_dist=41.5000, sc_score=0.7166
#   ✓ Processed successfully
#
# [129/612] Processing file: 3OXD_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3945, recovery=0.5756, edit_dist=34.5000, sc_score=0.6299
#   ✓ Processed successfully
#
# [130/612] Processing file: 3OXD_1_B.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3382, recovery=0.4826, edit_dist=40.0000, sc_score=0.7047
#   ✓ Processed successfully
#
# [131/612] Processing file: 3OXE_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3377, recovery=0.6279, edit_dist=31.0000, sc_score=0.6981
#   ✓ Processed successfully
#
# [132/612] Processing file: 3OXE_1_B.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.4062, recovery=0.5114, edit_dist=38.5000, sc_score=0.6940
#   ✓ Processed successfully
#
# [133/612] Processing file: 3OXJ_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3737, recovery=0.5349, edit_dist=34.5000, sc_score=0.6360
#   ✓ Processed successfully
#
# [134/612] Processing file: 3OXJ_1_B.fasta
#   Input sequence length: 85
#   Found 16 samples
#   Median metrics: perplexity=1.3550, recovery=0.5294, edit_dist=37.0000, sc_score=0.8150
#   ✓ Processed successfully
#
# [135/612] Processing file: 3OXM_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3399, recovery=0.5930, edit_dist=33.5000, sc_score=0.5987
#   ✓ Processed successfully
#
# [136/612] Processing file: 3OXM_1_B.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.3563, recovery=0.5230, edit_dist=38.5000, sc_score=0.8151
#   ✓ Processed successfully
#
# [137/612] Processing file: 3Q1Q_1_C.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.2664, recovery=0.6829, edit_dist=27.0000, sc_score=0.9260
#   ✓ Processed successfully
#
# [138/612] Processing file: 3Q1R_1_C.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.3150, recovery=0.6646, edit_dist=29.0000, sc_score=0.9260
#   ✓ Processed successfully
#
# [139/612] Processing file: 3RG5_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.2753, recovery=0.5407, edit_dist=35.0000, sc_score=0.5878
#   ✓ Processed successfully
#
# [140/612] Processing file: 3RG5_1_B.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.2722, recovery=0.6221, edit_dist=31.0000, sc_score=0.5336
#   ✓ Processed successfully
#
# [141/612] Processing file: 3S4P_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1747, recovery=0.8095, edit_dist=8.0000, sc_score=0.8799
#   ✓ Processed successfully
#
# [142/612] Processing file: 3TD0_1_B-A.fasta
#   Input sequence length: 42
#   Found 1 samples
#   Median metrics: perplexity=1.3425, recovery=0.8537, edit_dist=7.0000, sc_score=0.2112
#   ✓ Processed successfully
#
# [143/612] Processing file: 3TD1_1_B-A.fasta
#   Input sequence length: 43
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [144/612] Processing file: 3TRZ_1_U.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.6321, recovery=0.5250, edit_dist=9.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [145/612] Processing file: 3TRZ_1_V.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.7107, recovery=0.4500, edit_dist=9.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [146/612] Processing file: 3TRZ_1_W.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.5446, recovery=0.5500, edit_dist=9.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [147/612] Processing file: 3TRZ_1_X.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.6136, recovery=0.5000, edit_dist=9.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [148/612] Processing file: 3TRZ_1_Y.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.6231, recovery=0.5000, edit_dist=9.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [149/612] Processing file: 3TRZ_1_Z.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.6113, recovery=0.5000, edit_dist=9.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [150/612] Processing file: 3W3S_1_B.fasta
#   Input sequence length: 98
#   Found 16 samples
#   Median metrics: perplexity=1.3661, recovery=0.6122, edit_dist=37.0000, sc_score=0.5859
#   ✓ Processed successfully
#
# [151/612] Processing file: 3WRU_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2372, recovery=0.7500, edit_dist=10.0000, sc_score=0.9417
#   ✓ Processed successfully
#
# [152/612] Processing file: 3ZJV_1_B.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.1959, recovery=0.7976, edit_dist=17.0000, sc_score=0.5277
#   ✓ Processed successfully
#
# [153/612] Processing file: 462D_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.4123, recovery=0.6022, edit_dist=18.0000, sc_score=0.9205
#   ✓ Processed successfully
#
# [154/612] Processing file: 488D_1_D-B-A-C.fasta
#   Input sequence length: 65
#   Found 2 samples
#   Median metrics: perplexity=1.6361, recovery=0.4262, edit_dist=31.5000, sc_score=0.0764
#   ✓ Processed successfully
#
# [155/612] Processing file: 4AS1_1_B.fasta
#   Input sequence length: 82
#   Found 16 samples
#   Median metrics: perplexity=1.1707, recovery=0.7317, edit_dist=20.0000, sc_score=0.6939
#   ✓ Processed successfully
#
# [156/612] Processing file: 4CQN_1_B.fasta
#   Input sequence length: 82
#   Found 16 samples
#   Median metrics: perplexity=1.1789, recovery=0.7683, edit_dist=19.0000, sc_score=0.6778
#   ✓ Processed successfully
#
# [157/612] Processing file: 4F8V_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2346, recovery=0.8095, edit_dist=8.0000, sc_score=0.8799
#   ✓ Processed successfully
#
# [158/612] Processing file: 4GKJ_1_X-W.fasta
#   Input sequence length: 11
#   Found 15 samples
#   Median metrics: perplexity=2.4611, recovery=0.2000, edit_dist=7.0000, sc_score=0.6857
#   ✓ Processed successfully
#
# [159/612] Processing file: 4GPW_1_A-B.fasta
#   Input sequence length: 44
#   Found 16 samples
#   Median metrics: perplexity=1.1774, recovery=0.8182, edit_dist=8.0000, sc_score=0.9114
#   ✓ Processed successfully
#
# [160/612] Processing file: 4ILM_1_C.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.8917, recovery=0.4000, edit_dist=9.0000, sc_score=0.8128
#   ✓ Processed successfully
#
# [161/612] Processing file: 4ILM_1_E.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.9930, recovery=0.3333, edit_dist=9.0000, sc_score=0.8128
#   ✓ Processed successfully
#
# [162/612] Processing file: 4ILM_1_G.fasta
#   Input sequence length: 16
#   Found 15 samples
#   Median metrics: perplexity=1.6937, recovery=0.4000, edit_dist=9.0000, sc_score=0.8128
#   ✓ Processed successfully
#
# [163/612] Processing file: 4ILM_1_I.fasta
#   Input sequence length: 16
#   Found 15 samples
#   Median metrics: perplexity=2.1352, recovery=0.4000, edit_dist=9.0000, sc_score=0.4866
#   ✓ Processed successfully
#
# [164/612] Processing file: 4ILM_1_K.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.7201, recovery=0.4000, edit_dist=8.5000, sc_score=0.8128
#   ✓ Processed successfully
#
# [165/612] Processing file: 4ILM_1_M.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.9981, recovery=0.3667, edit_dist=9.0000, sc_score=0.6022
#   ✓ Processed successfully
#
# [166/612] Processing file: 4ILM_1_O.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.9171, recovery=0.3667, edit_dist=9.0000, sc_score=0.6022
#   ✓ Processed successfully
#
# [167/612] Processing file: 4ILM_1_R.fasta
#   Input sequence length: 16
#   Found 15 samples
#   Median metrics: perplexity=1.7050, recovery=0.4667, edit_dist=9.0000, sc_score=0.3917
#   ✓ Processed successfully
#
# [168/612] Processing file: 4K32_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2252, recovery=0.7738, edit_dist=9.5000, sc_score=0.9059
#   ✓ Processed successfully
#
# [169/612] Processing file: 4K4S_1_B-F-C-G-D-H.fasta
#   Input sequence length: 67
#   Found 16 samples
#   Median metrics: perplexity=1.6685, recovery=0.3615, edit_dist=37.0000, sc_score=0.8956
#   ✓ Processed successfully
#
# [170/612] Processing file: 4MCF_1_B-D-C-A.fasta
#   Input sequence length: 39
#   Found 14 samples
#   Median metrics: perplexity=1.5172, recovery=0.4444, edit_dist=19.0000, sc_score=0.9379
#   ✓ Processed successfully
#
# [171/612] Processing file: 4MGM_1_A.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.2064, recovery=0.6349, edit_dist=21.5000, sc_score=0.5262
#   ✓ Processed successfully
#
# [172/612] Processing file: 4MGM_1_B.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.1926, recovery=0.6349, edit_dist=21.5000, sc_score=0.4944
#   ✓ Processed successfully
#
# [173/612] Processing file: 4MSB_1_A-B.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.7828, recovery=0.4444, edit_dist=10.0000, sc_score=0.9324
#   ✓ Processed successfully
#
# [174/612] Processing file: 4MSB_1_C-D.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.6463, recovery=0.3889, edit_dist=11.5000, sc_score=0.9324
#   ✓ Processed successfully
#
# [175/612] Processing file: 4MSB_1_E-F.fasta
#   Input sequence length: 20
#   Found 15 samples
#   Median metrics: perplexity=1.6855, recovery=0.3889, edit_dist=9.0000, sc_score=0.9324
#   ✓ Processed successfully
#
# [176/612] Processing file: 4MSR_1_A-B.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.8345, recovery=0.4444, edit_dist=10.0000, sc_score=0.9324
#   ✓ Processed successfully
#
# [177/612] Processing file: 4O41_1_B-A.fasta
#   Input sequence length: 21
#   Found 16 samples
#   Median metrics: perplexity=1.7084, recovery=0.4000, edit_dist=11.5000, sc_score=0.7942
#   ✓ Processed successfully
#
# [178/612] Processing file: 4O41_1_C-D.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.6625, recovery=0.5000, edit_dist=8.5000, sc_score=0.8102
#   ✓ Processed successfully
#
# [179/612] Processing file: 4P20_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1933, recovery=0.7262, edit_dist=11.5000, sc_score=0.9417
#   ✓ Processed successfully
#
# [180/612] Processing file: 4P3S_1_B-A.fasta
#   Input sequence length: 41
#   Found 3 samples
#   Median metrics: perplexity=1.1629, recovery=0.8293, edit_dist=7.0000, sc_score=0.2217
#   ✓ Processed successfully
#
# [181/612] Processing file: 4PJO_1_1.fasta
#   Input sequence length: 47
#   Found 16 samples
#   Median metrics: perplexity=1.2994, recovery=0.4255, edit_dist=24.0000, sc_score=0.9254
#   ✓ Processed successfully
#
# [182/612] Processing file: 4PJO_1_2.fasta
#   Input sequence length: 47
#   Found 16 samples
#   Median metrics: perplexity=1.2761, recovery=0.4043, edit_dist=25.5000, sc_score=0.9254
#   ✓ Processed successfully
#
# [183/612] Processing file: 4PJO_1_3.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2487, recovery=0.3913, edit_dist=25.0000, sc_score=0.8562
#   ✓ Processed successfully
#
# [184/612] Processing file: 4PJO_1_4.fasta
#   Input sequence length: 48
#   Found 16 samples
#   Median metrics: perplexity=1.2828, recovery=0.3854, edit_dist=25.5000, sc_score=0.9254
#   ✓ Processed successfully
#
# [185/612] Processing file: 4PMI_1_A.fasta
#   Input sequence length: 40
#   Found 16 samples
#   Median metrics: perplexity=1.2179, recovery=0.5000, edit_dist=18.0000, sc_score=0.8951
#   ✓ Processed successfully
#
# [186/612] Processing file: 4QJD_1_B.fasta
#   Input sequence length: 46
#   Found 13 samples
#   Median metrics: perplexity=1.3825, recovery=0.4348, edit_dist=24.0000, sc_score=0.6744
#   ✓ Processed successfully
#
# [187/612] Processing file: 4QJD_1_D.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.3714, recovery=0.4348, edit_dist=23.5000, sc_score=0.7549
#   ✓ Processed successfully
#
# [188/612] Processing file: 4QJD_1_F.fasta
#   Input sequence length: 46
#   Found 13 samples
#   Median metrics: perplexity=1.4237, recovery=0.4348, edit_dist=24.0000, sc_score=0.7058
#   ✓ Processed successfully
#
# [189/612] Processing file: 4QJD_1_H.fasta
#   Input sequence length: 46
#   Found 12 samples
#   Median metrics: perplexity=1.4438, recovery=0.4456, edit_dist=24.0000, sc_score=0.6744
#   ✓ Processed successfully
#
# [190/612] Processing file: 4QJH_1_B.fasta
#   Input sequence length: 47
#   Found 8 samples
#   Median metrics: perplexity=1.5848, recovery=0.4149, edit_dist=22.0000, sc_score=0.7122
#   ✓ Processed successfully
#
# [191/612] Processing file: 4QJH_1_D.fasta
#   Input sequence length: 47
#   Found 11 samples
#   Median metrics: perplexity=1.6854, recovery=0.4043, edit_dist=22.0000, sc_score=0.7290
#   ✓ Processed successfully
#
# [192/612] Processing file: 4QJH_1_F.fasta
#   Input sequence length: 47
#   Found 9 samples
#   Median metrics: perplexity=1.5128, recovery=0.3617, edit_dist=24.0000, sc_score=0.6744
#   ✓ Processed successfully
#
# [193/612] Processing file: 4QPX_1_P-T.fasta
#   Input sequence length: 15
#   Found 16 samples
#   Median metrics: perplexity=1.8928, recovery=0.0769, edit_dist=9.5000, sc_score=0.8063
#   ✓ Processed successfully
#
# [194/612] Processing file: 4QYZ_1_L.fasta
#   Input sequence length: 55
#   Found 10 samples
#   Median metrics: perplexity=1.6032, recovery=0.3982, edit_dist=29.0000, sc_score=0.4699
#   ✓ Processed successfully
#
# [195/612] Processing file: 4RQE_1_B.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3775, recovery=0.5714, edit_dist=34.0000, sc_score=0.6070
#   ✓ Processed successfully
#
# [196/612] Processing file: 4RQE_1_D.fasta
#   Input sequence length: 83
#   Found 16 samples
#   Median metrics: perplexity=1.4744, recovery=0.4879, edit_dist=39.0000, sc_score=0.3808
#   ✓ Processed successfully
#
# [197/612] Processing file: 4TNA_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2352, recovery=0.6774, edit_dist=19.0000, sc_score=0.5223
#   ✓ Processed successfully
#
# [198/612] Processing file: 4TRA_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1926, recovery=0.7823, edit_dist=13.5000, sc_score=0.3621
#   ✓ Processed successfully
#
# [199/612] Processing file: 4TVX_1_L.fasta
#   Input sequence length: 60
#   Found 16 samples
#   Median metrics: perplexity=1.5440, recovery=0.3390, edit_dist=33.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [200/612] Processing file: 4TVX_1_X.fasta
#   Input sequence length: 59
#   Found 7 samples
#   Median metrics: perplexity=1.6871, recovery=0.4386, edit_dist=29.0000, sc_score=0.5756
#   ✓ Processed successfully
#
# [201/612] Processing file: 4U7U_1_L.fasta
#   Input sequence length: 61
#   Found 16 samples
#   Median metrics: perplexity=1.4230, recovery=0.4333, edit_dist=33.5000, sc_score=0.8655
#   ✓ Processed successfully
#
# [202/612] Processing file: 4U7U_1_X.fasta
#   Input sequence length: 61
#   Found 16 samples
#   Median metrics: perplexity=1.4506, recovery=0.4167, edit_dist=35.0000, sc_score=0.8655
#   ✓ Processed successfully
#
# [203/612] Processing file: 4V42_1_AB.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2794, recovery=0.7419, edit_dist=15.0000, sc_score=0.5653
#   ✓ Processed successfully
#
# [204/612] Processing file: 4V42_1_AC.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2501, recovery=0.7097, edit_dist=17.0000, sc_score=0.5557
#   ✓ Processed successfully
#
# [205/612] Processing file: 4V87_1_BB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2862, recovery=0.5517, edit_dist=35.0000, sc_score=0.3962
#   ✓ Processed successfully
#
# [206/612] Processing file: 4V87_1_CB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2862, recovery=0.5575, edit_dist=36.0000, sc_score=0.4696
#   ✓ Processed successfully
#
# [207/612] Processing file: 4V8B_1_AB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2981, recovery=0.5862, edit_dist=34.5000, sc_score=0.4567
#   ✓ Processed successfully
#
# [208/612] Processing file: 4V8B_1_CB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2473, recovery=0.5287, edit_dist=37.0000, sc_score=0.4608
#   ✓ Processed successfully
#
# [209/612] Processing file: 4V8C_1_CB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2471, recovery=0.5862, edit_dist=34.0000, sc_score=0.4831
#   ✓ Processed successfully
#
# [210/612] Processing file: 4V8C_1_DB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2239, recovery=0.5690, edit_dist=34.0000, sc_score=0.5296
#   ✓ Processed successfully
#
# [211/612] Processing file: 4V8D_1_AB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2965, recovery=0.6786, edit_dist=26.5000, sc_score=0.5467
#   ✓ Processed successfully
#
# [212/612] Processing file: 4V8D_1_AD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2715, recovery=0.6489, edit_dist=29.5000, sc_score=0.6329
#   ✓ Processed successfully
#
# [213/612] Processing file: 4V8D_1_CB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2709, recovery=0.6548, edit_dist=27.5000, sc_score=0.5976
#   ✓ Processed successfully
#
# [214/612] Processing file: 4V8D_1_CD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3000, recovery=0.6310, edit_dist=31.0000, sc_score=0.6249
#   ✓ Processed successfully
#
# [215/612] Processing file: 4V8E_1_BB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2932, recovery=0.6190, edit_dist=29.0000, sc_score=0.6194
#   ✓ Processed successfully
#
# [216/612] Processing file: 4V8E_1_BD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3377, recovery=0.6250, edit_dist=30.5000, sc_score=0.6519
#   ✓ Processed successfully
#
# [217/612] Processing file: 4V8E_1_DB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3050, recovery=0.6310, edit_dist=28.0000, sc_score=0.6278
#   ✓ Processed successfully
#
# [218/612] Processing file: 4V8E_1_DD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3367, recovery=0.6250, edit_dist=31.0000, sc_score=0.6336
#   ✓ Processed successfully
#
# [219/612] Processing file: 4V8F_1_BB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2636, recovery=0.6310, edit_dist=29.0000, sc_score=0.6675
#   ✓ Processed successfully
#
# [220/612] Processing file: 4V8F_1_BD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3226, recovery=0.6905, edit_dist=26.0000, sc_score=0.6210
#   ✓ Processed successfully
#
# [221/612] Processing file: 4V8F_1_CB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2947, recovery=0.6607, edit_dist=27.0000, sc_score=0.5573
#   ✓ Processed successfully
#
# [222/612] Processing file: 4V8F_1_CD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2887, recovery=0.5476, edit_dist=35.0000, sc_score=0.6081
#   ✓ Processed successfully
#
# [223/612] Processing file: 4W5O_1_B-D.fasta
#   Input sequence length: 30
#   Found 16 samples
#   Median metrics: perplexity=2.0099, recovery=0.3704, edit_dist=17.0000, sc_score=0.8794
#   ✓ Processed successfully
#
# [224/612] Processing file: 4W5Q_1_B-D.fasta
#   Input sequence length: 28
#   Found 15 samples
#   Median metrics: perplexity=1.8070, recovery=0.4231, edit_dist=16.0000, sc_score=0.9340
#   ✓ Processed successfully
#
# [225/612] Processing file: 4W5T_1_B-D.fasta
#   Input sequence length: 26
#   Found 16 samples
#   Median metrics: perplexity=1.8165, recovery=0.3333, edit_dist=15.0000, sc_score=0.8629
#   ✓ Processed successfully
#
# [226/612] Processing file: 4WR6_1_1L.fasta
#   Input sequence length: 85
#   Found 16 samples
#   Median metrics: perplexity=1.2780, recovery=0.6471, edit_dist=29.0000, sc_score=0.2510
#   ✓ Processed successfully
#
# [227/612] Processing file: 4WR6_1_3L.fasta
#   Input sequence length: 85
#   Found 16 samples
#   Median metrics: perplexity=1.4116, recovery=0.6235, edit_dist=30.5000, sc_score=0.2417
#   ✓ Processed successfully
#
# [228/612] Processing file: 4WRA_1_1L.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3331, recovery=0.6667, edit_dist=27.5000, sc_score=0.4970
#   ✓ Processed successfully
#
# [229/612] Processing file: 4WRA_1_3K.fasta
#   Input sequence length: 84
#   Found 14 samples
#   Median metrics: perplexity=1.2956, recovery=0.5952, edit_dist=31.0000, sc_score=0.6201
#   ✓ Processed successfully
#
# [230/612] Processing file: 4WRA_1_3L.fasta
#   Input sequence length: 83
#   Found 14 samples
#   Median metrics: perplexity=1.4140, recovery=0.6325, edit_dist=29.0000, sc_score=0.3419
#   ✓ Processed successfully
#
# [231/612] Processing file: 4WSM_1_1K.fasta
#   Input sequence length: 83
#   Found 16 samples
#   Median metrics: perplexity=1.3458, recovery=0.5783, edit_dist=34.0000, sc_score=0.5097
#   ✓ Processed successfully
#
# [232/612] Processing file: 4WSM_1_1L.fasta
#   Input sequence length: 83
#   Found 16 samples
#   Median metrics: perplexity=1.3722, recovery=0.5482, edit_dist=34.5000, sc_score=0.4874
#   ✓ Processed successfully
#
# [233/612] Processing file: 4X4N_1_G.fasta
#   Input sequence length: 20
#   Found 15 samples
#   Median metrics: perplexity=1.7702, recovery=0.3000, edit_dist=12.0000, sc_score=0.6149
#   ✓ Processed successfully
#
# [234/612] Processing file: 4X4U_1_G.fasta
#   Input sequence length: 18
#   Found 16 samples
#   Median metrics: perplexity=1.8489, recovery=0.2353, edit_dist=12.0000, sc_score=0.9320
#   ✓ Processed successfully
#
# [235/612] Processing file: 4Z4C_1_B-D.fasta
#   Input sequence length: 28
#   Found 16 samples
# ...
#   Input sequence length: 58
#   Found 16 samples
#   Median metrics: perplexity=1.4472, recovery=0.2759, edit_dist=31.0000, sc_score=0.7509
#   ✓ Processed successfully
#
# [540/612] Processing file: 7XJG_1_H.fasta
#   Input sequence length: 58
#   Found 16 samples
#   Median metrics: perplexity=1.5398, recovery=0.2672, edit_dist=31.0000, sc_score=0.6113
#   ✓ Processed successfully
#
# [541/612] Processing file: 7Y7P_1_E-J.fasta
#   Input sequence length: 17
#   Found 16 samples
#   Median metrics: perplexity=2.0389, recovery=0.3125, edit_dist=10.0000, sc_score=0.2680
#   ✓ Processed successfully
#
# [542/612] Processing file: 7Y7Q_1_C-D.fasta
#   Input sequence length: 17
#   Found 16 samples
#   Median metrics: perplexity=1.9940, recovery=0.1562, edit_dist=11.0000, sc_score=0.8099
#   ✓ Processed successfully
#
# [543/612] Processing file: 7Y82_1_B-C.fasta
#   Input sequence length: 66
#   Found 16 samples
#   Median metrics: perplexity=1.2928, recovery=0.5909, edit_dist=24.0000, sc_score=0.8744
#   ✓ Processed successfully
#
# [544/612] Processing file: 7Y9Y_1_R-D.fasta
#   Input sequence length: 61
#   Found 16 samples
#   Median metrics: perplexity=1.3569, recovery=0.4750, edit_dist=30.5000, sc_score=0.9018
#   ✓ Processed successfully
#
# [545/612] Processing file: 7YNA_1_B-C.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.3469, recovery=0.4286, edit_dist=30.0000, sc_score=0.9379
#   ✓ Processed successfully
#
# [546/612] Processing file: 7YNB_1_B-C.fasta
#   Input sequence length: 66
#   Found 16 samples
#   Median metrics: perplexity=1.3733, recovery=0.4697, edit_dist=32.5000, sc_score=0.9091
#   ✓ Processed successfully
#
# [547/612] Processing file: 7YNC_1_B-C.fasta
#   Input sequence length: 66
#   Found 16 samples
#   Median metrics: perplexity=1.3742, recovery=0.4242, edit_dist=34.0000, sc_score=0.9264
#   ✓ Processed successfully
#
# [548/612] Processing file: 7YOJ_1_B.fasta
#   Input sequence length: 174
#   Found 16 samples
#   Median metrics: perplexity=1.6555, recovery=0.2989, edit_dist=93.0000, sc_score=0.4802
#   ✓ Processed successfully
#
# [549/612] Processing file: 7YR6_1_A.fasta
#   Input sequence length: 118
#   Found 16 samples
#   Median metrics: perplexity=1.4981, recovery=0.3771, edit_dist=61.0000, sc_score=0.6871
#   ✓ Processed successfully
#
# [550/612] Processing file: 7YR7_1_A.fasta
#   Input sequence length: 118
#   Found 16 samples
#   Median metrics: perplexity=1.5926, recovery=0.3305, edit_dist=63.0000, sc_score=0.5806
#   ✓ Processed successfully
#
# [551/612] Processing file: 7YYM_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.7542, recovery=0.4434, edit_dist=28.5000, sc_score=0.8765
#   ✓ Processed successfully
#
# [552/612] Processing file: 7YYN_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.5994, recovery=0.4818, edit_dist=26.5000, sc_score=0.8588
#   ✓ Processed successfully
#
# [553/612] Processing file: 7ZJW_1_F.fasta
#   Input sequence length: 90
#   Found 16 samples
#   Median metrics: perplexity=1.3678, recovery=0.5389, edit_dist=36.5000, sc_score=0.5171
#   ✓ Processed successfully
#
# [554/612] Processing file: 7ZPI_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.5303, recovery=0.4545, edit_dist=27.0000, sc_score=0.8944
#   ✓ Processed successfully
#
# [555/612] Processing file: 7ZPJ_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.6059, recovery=0.4909, edit_dist=26.0000, sc_score=0.9141
#   ✓ Processed successfully
#
# [556/612] Processing file: 7ZPK_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.6295, recovery=0.4818, edit_dist=28.0000, sc_score=0.8788
#   ✓ Processed successfully
#
# [557/612] Processing file: 8A3L_1_V.fasta
#   Input sequence length: 73
#   Found 16 samples
#   Median metrics: perplexity=1.1360, recovery=0.9041, edit_dist=7.0000, sc_score=0.4855
#   ✓ Processed successfully
#
# [558/612] Processing file: 8ANY_1_AA.fasta
#   Input sequence length: 949
#   Found 16 samples
#   Median metrics: perplexity=1.2473, recovery=0.6891, edit_dist=281.5000, sc_score=0.4073
#   ✓ Processed successfully
#
# [559/612] Processing file: 8AS7_1_P-T-G.fasta
#   Input sequence length: 37
#   Found 15 samples
#   Median metrics: perplexity=1.4829, recovery=0.4722, edit_dist=20.0000, sc_score=0.5529
#   ✓ Processed successfully
#
# [560/612] Processing file: 8ASB_1_P-T-G.fasta
#   Input sequence length: 38
#   Found 15 samples
#   Median metrics: perplexity=1.4133, recovery=0.3784, edit_dist=24.0000, sc_score=0.5266
#   ✓ Processed successfully
#
# [561/612] Processing file: 8C6J_1_2-6.fasta
#   Input sequence length: 239
#   Found 16 samples
#   Median metrics: perplexity=1.5017, recovery=0.4937, edit_dist=105.0000, sc_score=0.4872
#   ✓ Processed successfully
#
# [562/612] Processing file: 8CA7_1_A.fasta
#   Input sequence length: 498
#   Found 16 samples
#   Median metrics: perplexity=1.0813, recovery=0.9639, edit_dist=17.0000, sc_score=0.5977
#   ✓ Processed successfully
#
# [563/612] Processing file: 8CAS_1_1.fasta
#   Input sequence length: 64
#   Found 16 samples
#   Median metrics: perplexity=1.3662, recovery=0.6094, edit_dist=21.5000, sc_score=0.6119
#   ✓ Processed successfully
#
# [564/612] Processing file: 8CAZ_1_A.fasta
#   Input sequence length: 457
#   Found 16 samples
#   Median metrics: perplexity=1.0716, recovery=0.9792, edit_dist=9.5000, sc_score=0.4868
#   ✓ Processed successfully
#
# [565/612] Processing file: 8CF1_1_A.fasta
#   Input sequence length: 481
#   Found 16 samples
#   Median metrics: perplexity=1.0754, recovery=0.9771, edit_dist=11.0000, sc_score=0.4451
#   ✓ Processed successfully
#
# [566/612] Processing file: 8CF8_1_A.fasta
#   Input sequence length: 457
#   Found 16 samples
#   Median metrics: perplexity=1.0696, recovery=0.9825, edit_dist=8.0000, sc_score=0.4730
#   ✓ Processed successfully
#
# [567/612] Processing file: 8CGI_1_A.fasta
#   Input sequence length: 457
#   Found 16 samples
#   Median metrics: perplexity=1.0709, recovery=0.9836, edit_dist=7.5000, sc_score=0.4886
#   ✓ Processed successfully
#
# [568/612] Processing file: 8CSP_1_A.fasta
#   Input sequence length: 737
#   Found 16 samples
#   Median metrics: perplexity=1.2994, recovery=0.5563, edit_dist=291.5000, sc_score=0.4010
#   ✓ Processed successfully
#
# [569/612] Processing file: 8CSQ_1_A.fasta
#   Input sequence length: 802
#   Found 16 samples
#   Median metrics: perplexity=1.2829, recovery=0.5530, edit_dist=320.0000, sc_score=0.4230
#   ✓ Processed successfully
#
# [570/612] Processing file: 8CSR_1_A.fasta
#   Input sequence length: 853
#   Found 16 samples
#   Median metrics: perplexity=1.2649, recovery=0.5680, edit_dist=332.0000, sc_score=0.4359
#   ✓ Processed successfully
#
# [571/612] Processing file: 8CSS_1_A.fasta
#   Input sequence length: 844
#   Found 16 samples
#   Median metrics: perplexity=1.2580, recovery=0.5906, edit_dist=311.5000, sc_score=0.4276
#   ✓ Processed successfully
#
# [572/612] Processing file: 8CST_1_A.fasta
#   Input sequence length: 886
#   Found 16 samples
#   Median metrics: perplexity=1.2813, recovery=0.5948, edit_dist=333.5000, sc_score=0.3869
#   ✓ Processed successfully
#
# [573/612] Processing file: 8CSU_1_A.fasta
#   Input sequence length: 881
#   Found 16 samples
#   Median metrics: perplexity=1.2834, recovery=0.5727, edit_dist=344.0000, sc_score=0.3947
#   ✓ Processed successfully
#
# [574/612] Processing file: 8CVO_1_A.fasta
#   Input sequence length: 469
#   Found 16 samples
#   Median metrics: perplexity=1.1231, recovery=0.8102, edit_dist=82.5000, sc_score=0.3264
#   ✓ Processed successfully
#
# [575/612] Processing file: 8E0F_1_D-C.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.6719, recovery=0.3443, edit_dist=30.0000, sc_score=0.9637
#   ✓ Processed successfully
#
# [576/612] Processing file: 8E40_1_r-R.fasta
#   Input sequence length: 47
#   Found 16 samples
#   Median metrics: perplexity=1.6996, recovery=0.1702, edit_dist=38.0000, sc_score=0.8629
#   ✓ Processed successfully
#
# [577/612] Processing file: 8E4X_1_C-D.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.5469, recovery=0.2417, edit_dist=30.0000, sc_score=0.9637
#   ✓ Processed successfully
#
# [578/612] Processing file: 8E5T_1_1-2.fasta
#   Input sequence length: 881
#   Found 16 samples
#   Median metrics: perplexity=1.2319, recovery=0.6946, edit_dist=244.0000, sc_score=0.5702
#   ✓ Processed successfully
#
# [579/612] Processing file: 8EEY_1_C-D.fasta
#   Input sequence length: 66
#   Found 16 samples
#   Median metrics: perplexity=1.3910, recovery=0.3828, edit_dist=34.0000, sc_score=0.9245
#   ✓ Processed successfully
#
# [580/612] Processing file: 8FJK_1_a1-b1.fasta
#   Input sequence length: 104
#   Found 16 samples
#   Median metrics: perplexity=1.5387, recovery=0.5539, edit_dist=33.5000, sc_score=0.9899
#   ✓ Processed successfully
#
# [581/612] Processing file: 8FJK_1_a2-b2.fasta
#   Input sequence length: 120
#   Found 16 samples
#   Median metrics: perplexity=1.5454, recovery=0.4915, edit_dist=43.0000, sc_score=0.9913
#   ✓ Processed successfully
#
# [582/612] Processing file: 8FJK_1_a3-b3.fasta
#   Input sequence length: 80
#   Found 16 samples
#   Median metrics: perplexity=1.4544, recovery=0.6346, edit_dist=20.5000, sc_score=0.9866
#   ✓ Processed successfully
#
# [583/612] Processing file: 8FJL_1_a1-b1.fasta
#   Input sequence length: 104
#   Found 16 samples
#   Median metrics: perplexity=1.5715, recovery=0.5245, edit_dist=35.0000, sc_score=0.9899
#   ✓ Processed successfully
#
# [584/612] Processing file: 8FJL_1_a2-b2.fasta
#   Input sequence length: 120
#   Found 16 samples
#   Median metrics: perplexity=1.6188, recovery=0.5042, edit_dist=42.5000, sc_score=0.9913
#   ✓ Processed successfully
#
# [585/612] Processing file: 8FJL_1_a3-b3.fasta
#   Input sequence length: 80
#   Found 16 samples
#   Median metrics: perplexity=1.5526, recovery=0.5064, edit_dist=28.0000, sc_score=0.9866
#   ✓ Processed successfully
#
# [586/612] Processing file: 8FKP_1_L2.fasta
#   Input sequence length: 69
#   Found 10 samples
#   Median metrics: perplexity=1.3356, recovery=0.4566, edit_dist=35.5000, sc_score=0.4783
#   ✓ Processed successfully
#
# [587/612] Processing file: 8FKQ_1_L2.fasta
#   Input sequence length: 69
#   Found 10 samples
#   Median metrics: perplexity=1.2945, recovery=0.4710, edit_dist=35.5000, sc_score=0.5034
#   ✓ Processed successfully
#
# [588/612] Processing file: 8FKR_1_L2.fasta
#   Input sequence length: 69
#   Found 12 samples
#   Median metrics: perplexity=1.2809, recovery=0.4783, edit_dist=35.0000, sc_score=0.5150
#   ✓ Processed successfully
#
# [589/612] Processing file: 8FKS_1_L2.fasta
#   Input sequence length: 69
#   Found 11 samples
#   Median metrics: perplexity=1.3032, recovery=0.4638, edit_dist=35.0000, sc_score=0.5469
#   ✓ Processed successfully
#
# [590/612] Processing file: 8FKT_1_L2.fasta
#   Input sequence length: 69
#   Found 12 samples
#   Median metrics: perplexity=1.3446, recovery=0.4566, edit_dist=35.0000, sc_score=0.4897
#   ✓ Processed successfully
#
# [591/612] Processing file: 8FKU_1_L2.fasta
#   Input sequence length: 69
#   Found 14 samples
#   Median metrics: perplexity=1.3079, recovery=0.4638, edit_dist=34.0000, sc_score=0.4775
#   ✓ Processed successfully
#
# [592/612] Processing file: 8FKV_1_L2.fasta
#   Input sequence length: 69
#   Found 13 samples
#   Median metrics: perplexity=1.3276, recovery=0.4783, edit_dist=34.0000, sc_score=0.5327
#   ✓ Processed successfully
#
# [593/612] Processing file: 8FKW_1_L2.fasta
#   Input sequence length: 69
#   Found 15 samples
#   Median metrics: perplexity=1.3212, recovery=0.4783, edit_dist=33.0000, sc_score=0.5196
#   ✓ Processed successfully
#
# [594/612] Processing file: 8FKX_1_L2.fasta
#   Input sequence length: 69
#   Found 13 samples
#   Median metrics: perplexity=1.2906, recovery=0.4783, edit_dist=34.0000, sc_score=0.4835
#   ✓ Processed successfully
#
# [595/612] Processing file: 8FKY_1_L2.fasta
#   Input sequence length: 69
#   Found 10 samples
#   Median metrics: perplexity=1.2888, recovery=0.4856, edit_dist=34.0000, sc_score=0.5255
#   ✓ Processed successfully
#
# [596/612] Processing file: 8FKZ_1_L2.fasta
#   Input sequence length: 68
#   Found 14 samples
#   Median metrics: perplexity=1.2833, recovery=0.4779, edit_dist=33.0000, sc_score=0.5072
#   ✓ Processed successfully
#
# [597/612] Processing file: 8FL2_1_L2.fasta
#   Input sequence length: 72
#   Found 14 samples
#   Median metrics: perplexity=1.3407, recovery=0.4306, edit_dist=35.5000, sc_score=0.5138
#   ✓ Processed successfully
#
# [598/612] Processing file: 8FL6_1_L2.fasta
#   Input sequence length: 72
#   Found 16 samples
#   Median metrics: perplexity=1.4108, recovery=0.4444, edit_dist=35.5000, sc_score=0.5138
#   ✓ Processed successfully
#
# [599/612] Processing file: 8FLA_1_L2.fasta
#   Input sequence length: 72
#   Found 14 samples
#   Median metrics: perplexity=1.3567, recovery=0.4444, edit_dist=36.0000, sc_score=0.5077
#   ✓ Processed successfully
#
# [600/612] Processing file: 8FLD_1_L2.fasta
#   Input sequence length: 72
#   Found 16 samples
#   Median metrics: perplexity=1.4005, recovery=0.4167, edit_dist=36.0000, sc_score=0.5331
#   ✓ Processed successfully
#
# [601/612] Processing file: 8G9Z_1_E.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2731, recovery=0.6118, edit_dist=33.0000, sc_score=0.6019
#   ✓ Processed successfully
#
# [602/612] Processing file: 8GS2_1_R-D.fasta
#   Input sequence length: 61
#   Found 16 samples
#   Median metrics: perplexity=1.3237, recovery=0.4750, edit_dist=29.5000, sc_score=0.9263
#   ✓ Processed successfully
#
# [603/612] Processing file: 8GWB_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.7526, recovery=0.3366, edit_dist=26.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [604/612] Processing file: 8GWE_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.6191, recovery=0.3462, edit_dist=26.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [605/612] Processing file: 8GWF_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.6191, recovery=0.3462, edit_dist=26.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [606/612] Processing file: 8GWG_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.6191, recovery=0.3462, edit_dist=26.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [607/612] Processing file: 8GWI_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.6191, recovery=0.3462, edit_dist=26.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [608/612] Processing file: 8GWN_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.7323, recovery=0.3366, edit_dist=26.5000, sc_score=0.9076
#   ✓ Processed successfully
#
# [609/612] Processing file: 8GWO_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.7300, recovery=0.3269, edit_dist=25.0000, sc_score=0.9353
#   ✓ Processed successfully
#
# [610/612] Processing file: 8HMY_1_T.fasta
#   Input sequence length: 90
#   Found 16 samples
#   Median metrics: perplexity=1.2723, recovery=0.6333, edit_dist=31.5000, sc_score=0.7621
#   ✓ Processed successfully
#
# [611/612] Processing file: 8I3Q_1_C.fasta
#   Input sequence length: 95
#   Found 16 samples
#   Median metrics: perplexity=1.3484, recovery=0.5842, edit_dist=36.0000, sc_score=0.5394
#   ✓ Processed successfully
#
# [612/612] Processing file: 8JOZ_1_B.fasta
#   Input sequence length: 79
#   Found 16 samples
#   Median metrics: perplexity=1.3120, recovery=0.6456, edit_dist=24.0000, sc_score=0.6152
#   ✓ Processed successfully
#
# === Processing Completed ===
# Total files: 612
# Successfully processed: 602
# Failed: 10
# Results saved to: ./data/gr_1_seed4.txt
#
# Results preview (first 5 lines):
#   63 1.2711 0.6667 21.0000 0.8121
#   63 1.2607 0.6429 22.5000 0.7189
#   33 1.3628 0.6406 12.5000 0.5989
#   62 1.2371 0.7419 15.0000 0.6084
#   62 1.2560 0.7581 13.0000 0.4957
#   ... (total 602 lines)
#
# === Validate Output Format ===
# Total lines: 602
# Line 1: length=63, perplexity=1.2711, recovery=0.6667, edit_dist=21.0, sc_score=0.8121
# Line 2: length=63, perplexity=1.2607, recovery=0.6429, edit_dist=22.5, sc_score=0.7189
# Line 3: length=33, perplexity=1.3628, recovery=0.6406, edit_dist=12.5, sc_score=0.5989

# %%
### Single seed RNA Design Data Analysis Script###
def analyze_rna_data(filename="./data/v11s4.txt"):#Just change the filename or path to analyze different data files
    """
    Read our .fasta files,
    length (int)
    recovery (float)
    scc (float)
    """
    if not os.path.exists(filename):
        print(f"Error: '{filename}' is not found in the current directory.")
        return

    # Create data buckets for three length ranges
    range_small = []  # 0-100 nt
    range_medium = [] # 101-200 nt
    range_large = []  # >200 nt

    with open(filename, 'r') as f:
        for line in f:
            # Try to parse each line
            try:
                parts = line.strip().split()
                # Ensure the line has enough data columns
                if len(parts) >= 5:
                    length = int(parts[0])
                    recovery = float(parts[2])
                    scc = float(parts[4])
                    if length <= 100:
                        range_small.append([recovery, scc])
                    elif 100 < length <= 200:
                        range_medium.append([recovery, scc])
                    else: # length > 200
                        range_large.append([recovery, scc])
            except (ValueError, IndexError):
                continue

    # Define a function to calculate statistics and return a dictionary
    def calculate_statistics(data):
        if not data:
            return {
                "mean_recovery": 0.0, "median_recovery": 0.0,
                "mean_scc": 0.0, "median_scc": 0.0
            }

        data_np = np.array(data)
        recoveries = data_np[:, 0]
        sccs = data_np[:, 1]
        
        return {
            "mean_recovery": np.mean(recoveries),
            "median_recovery": np.median(recoveries),
            "mean_scc": np.mean(sccs),
            "median_scc": np.median(sccs)
        }

    stats_small = calculate_statistics(range_small)
    stats_medium = calculate_statistics(range_medium)
    stats_large = calculate_statistics(range_large)

    print(f"Reading {filename} ...")
    print("           & Recovery (0-100) & Recovery (100-200) & Recovery (>200) & SC Score (0-100) & SC Score (100-200) & SC Score (>200)")
    
    mean_line = (
        f"Average:    & {stats_small['mean_recovery']:.3f} & {stats_medium['mean_recovery']:.3f} & {stats_large['mean_recovery']:.3f} & "
        f"{stats_small['mean_scc']:.3f} & {stats_medium['mean_scc']:.3f} & {stats_large['mean_scc']:.3f}"
    )

    median_line = (
        f"Median:     & {stats_small['median_recovery']:.3f} & {stats_medium['median_recovery']:.3f} & {stats_large['median_recovery']:.3f} & "
        f"{stats_small['median_scc']:.3f} & {stats_medium['median_scc']:.3f} & {stats_large['median_scc']:.3f}"
    )

    print(mean_line)
    print(median_line)


if __name__ == "__main__":
    analyze_rna_data()
# Out:
# Reading ./data/v11s0.txt ...
#            & Recovery (0-100) & Recovery (100-200) & Recovery (>200) & SC Score (0-100) & SC Score (100-200) & SC Score (>200)
# Average:    & 0.521 & 0.588 & 0.706 & 0.712 & 0.635 & 0.414
# Median:     & 0.488 & 0.560 & 0.693 & 0.769 & 0.618 & 0.403

# %%
def analyze_mean_stability(filenames: List[str]):
    for filename in filenames:
        if not os.path.exists(filename):
            print(f"Error: '{filename}' is not found in the current directory.")
            return
###### We will take the Average for each file, and then compute the mean ± standard deviation across those average values.######
    small_recovery_means, medium_recovery_means, large_recovery_means = [], [], []
    small_scc_means, medium_scc_means, large_scc_means = [], [], []

    for filename in filenames:
        range_small, range_medium, range_large = [], [], [] 
        with open(filename, 'r') as f:
            for line in f:
                try:
                    parts = line.strip().split()
                    if len(parts) >= 5:
                        length = int(parts[0])
                        recovery = float(parts[2])
                        scc = float(parts[4])
                        
                        if length <= 100:
                            range_small.append([recovery, scc])
                        elif 100 < length <= 200:
                            range_medium.append([recovery, scc])
                        else:
                            range_large.append([recovery, scc])
                except (ValueError, IndexError):
                    continue

        if range_small:
            small_recovery_means.append(np.mean(np.array(range_small)[:, 0]))
            small_scc_means.append(np.mean(np.array(range_small)[:, 1]))
        if range_medium:
            medium_recovery_means.append(np.mean(np.array(range_medium)[:, 0]))
            medium_scc_means.append(np.mean(np.array(range_medium)[:, 1]))
        if range_large:
            large_recovery_means.append(np.mean(np.array(range_large)[:, 0]))
            large_scc_means.append(np.mean(np.array(range_large)[:, 1]))

    def calculate_stats_of_means(means_list):
        if not means_list:
            return 0.0, 0.0
        return np.mean(means_list), np.std(means_list)

    mean_rec_small, std_rec_small = calculate_stats_of_means(small_recovery_means)
    mean_rec_medium, std_rec_medium = calculate_stats_of_means(medium_recovery_means)
    mean_rec_large, std_rec_large = calculate_stats_of_means(large_recovery_means)
    
    mean_scc_small, std_scc_small = calculate_stats_of_means(small_scc_means)
    mean_scc_medium, std_scc_medium = calculate_stats_of_means(medium_scc_means)
    mean_scc_large, std_scc_large = calculate_stats_of_means(large_scc_means)

    print("\n--- Multiple Seed Experiments [Average] Stability Analysis ---")
    print(f"Reading {', '.join(filenames)}...")

    result_line_recovery = (
        f"Recovery (Mean): & "
        f"{mean_rec_small:.3f} ± {std_rec_small:.3f} & "
        f"{mean_rec_medium:.3f} ± {std_rec_medium:.3f} & "
        f"{mean_rec_large:.3f} ± {std_rec_large:.3f}"
    )
    result_line_scc = (
        f"SC Score (Mean): & "
        f"{mean_scc_small:.3f} ± {std_scc_small:.3f} & "
        f"{mean_scc_medium:.3f} ± {std_scc_medium:.3f} & "
        f"{mean_scc_large:.3f} ± {std_scc_large:.3f}"
    )

    print("Average               & 0-100 nt     & 100-200 nt     & >200 nt")
    print("-" * 90)
    print(result_line_recovery)
    print(result_line_scc)

def analyze_median_stability(filenames: List[str]):
###### We will take the median for each file, and then compute the mean ± standard deviation across those median values.######
    for filename in filenames:
        if not os.path.exists(filename):
            print(f"Error: '{filename}' is not found in the current directory.")
            return

    small_recovery_medians, medium_recovery_medians, large_recovery_medians = [], [], []
    small_scc_medians, medium_scc_medians, large_scc_medians = [], [], []

    for filename in filenames:
        range_small, range_medium, range_large = [], [], []
        
        with open(filename, 'r') as f:
            for line in f:
                try:
                    parts = line.strip().split()
                    if len(parts) >= 5:
                        length = int(parts[0])
                        recovery = float(parts[2])
                        scc = float(parts[4])
                        
                        if length <= 100:
                            range_small.append([recovery, scc])
                        elif 100 < length <= 200:
                            range_medium.append([recovery, scc])
                        else:
                            range_large.append([recovery, scc])
                except (ValueError, IndexError):
                    continue
        
        if range_small:
            small_recovery_medians.append(np.median(np.array(range_small)[:, 0]))
            small_scc_medians.append(np.median(np.array(range_small)[:, 1]))
        if range_medium:
            medium_recovery_medians.append(np.median(np.array(range_medium)[:, 0]))
            medium_scc_medians.append(np.median(np.array(range_medium)[:, 1]))
        if range_large:
            large_recovery_medians.append(np.median(np.array(range_large)[:, 0]))
            large_scc_medians.append(np.median(np.array(range_large)[:, 1]))

    def calculate_stats_of_medians(medians_list):
        if not medians_list:
            return 0.0, 0.0
        return np.mean(medians_list), np.std(medians_list)

    mean_rec_small, std_rec_small = calculate_stats_of_medians(small_recovery_medians)
    mean_rec_medium, std_rec_medium = calculate_stats_of_medians(medium_recovery_medians)
    mean_rec_large, std_rec_large = calculate_stats_of_medians(large_recovery_medians)
    
    mean_scc_small, std_scc_small = calculate_stats_of_medians(small_scc_medians)
    mean_scc_medium, std_scc_medium = calculate_stats_of_medians(medium_scc_medians)
    mean_scc_large, std_scc_large = calculate_stats_of_medians(large_scc_medians)

    print("\n--- Multiple Seed Experiments [Median] Stability Analysis ---")
    print(f"Reading {', '.join(filenames)} ...")

    result_line_recovery = (
        f"Recovery (Median): & "
        f"{mean_rec_small:.3f} ± {std_rec_small:.3f} & "
        f"{mean_rec_medium:.3f} ± {std_rec_medium:.3f} & "
        f"{mean_rec_large:.3f} ± {std_rec_large:.3f}"
    )
    result_line_scc = (
        f"SC Score (Median): & "
        f"{mean_scc_small:.3f} ± {std_scc_small:.3f} & "
        f"{mean_scc_medium:.3f} ± {std_scc_medium:.3f} & "
        f"{mean_scc_large:.3f} ± {std_scc_large:.3f}"
    )

    print("Median                & 0-100 nt     & 100-200 nt     & >200 nt")
    print("-" * 90)
    print(result_line_recovery)
    print(result_line_scc)


if __name__ == "__main__":
    files_to_analyze = [
        "./data/gvpa1s4_avg.txt", 
        "./data/gvpa1s1_avg.txt", 
        "./data/gvpa1s0_avg.txt"
    ]
    
    analyze_mean_stability(files_to_analyze)
    analyze_median_stability(files_to_analyze)
# Out:
# --- Multiple Seed Experiments [Average] Stability Analysis ---
# Reading ./data/gr_1_seed4_avg.txt, ./data/gr_1_seed42_avg.txt, ./data/gr_1_seed2_avg.txt...
# Average               & 0-100 nt     & 100-200 nt     & >200 nt
# ------------------------------------------------------------------------------------------
# Recovery (Mean): & 0.511 ± 0.004 & 0.521 ± 0.038 & 0.673 ± 0.010
# SC Score (Mean): & 0.684 ± 0.009 & 0.602 ± 0.025 & 0.391 ± 0.013
#
# --- Multiple Seed Experiments [Median] Stability Analysis ---
# Reading ./data/gr_1_seed4_avg.txt, ./data/gr_1_seed42_avg.txt, ./data/gr_1_seed2_avg.txt ...
# Median                & 0-100 nt     & 100-200 nt     & >200 nt
# ------------------------------------------------------------------------------------------
# Recovery (Median): & 0.493 ± 0.005 & 0.497 ± 0.017 & 0.610 ± 0.019
# SC Score (Median): & 0.703 ± 0.014 & 0.564 ± 0.062 & 0.379 ± 0.018

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# --- UPDATED Data extracted from the new image ---
# List of models to plot
models = [
    'gRNAde',
    'long-short',
    'gat',
    'gat_gate_0.5',          # Renamed from 'gat_gvp_0.5' for simplicity
    'TransformerHead_0.3',
    'GVPAttention_lr1e-4', # New model
    'GVPAttention_lr2e-4'  # New model
]
# Corresponding names for the legend
legend_names = [
    'gRNAde',
    'long-short transformer(window=16)',
    'gat transformer',
    'gat transformer(gate=0.5)',     # Updated legend name
    'TransformerHead(gate=0.3)',
    'GVPAttention(lr=0.0001)',     # New legend name
    'GVPAttention(lr=0.0002)'      # New legend name
]


ranges = ['Short (0-100 nt)', 'Medium (100-200 nt)', 'Long (>200 nt)'] # Range labels in English

# Updated data dictionary based on Table 3 ONLY
data = {
    'Average Recovery': {
        'gRNAde': [0.509, 0.530, 0.673],
        'long-short': [0.487, 0.454, 0.707],
        'gat': [0.472, 0.467, 0.713],
        'gat_gate_0.5': [0.487, 0.465, 0.693],         # Data for gat(gate=0.5)
        'TransformerHead_0.3': [0.498, 0.481, 0.730],
        'GVPAttention_lr1e-4': [0.515, 0.550, 0.679], # New data
        'GVPAttention_lr2e-4': [0.524, 0.569, 0.698]  # New data
    },
    'Average SC Score': {
        'gRNAde': [0.691, 0.607, 0.393],
        'long-short': [0.692, 0.637, 0.398],
        'gat': [0.693, 0.631, 0.415],
        'gat_gate_0.5': [0.695, 0.637, 0.432],         # Data for gat(gate=0.5)
        'TransformerHead_0.3': [0.692, 0.635, 0.418],
        'GVPAttention_lr1e-4': [0.699, 0.607, 0.399], # New data
        'GVPAttention_lr2e-4': [0.688, 0.576, 0.403]  # New data
    }
    # Median data is NOT included as it was not provided in the new image
}
# --- END UPDATED DATA ---

# --- Plotting Function (Unchanged from previous successful version) ---
def plot_metric_comparison(metric_name, data_dict, models_list, legend_names_list, ranges_list):
    """
    Plots a compact bar chart comparing the specified metric across different sequence
    length ranges and different models, with horizontal value labels above bars and an
    auto-placed legend inside. Saves the plot.

    Args:
        metric_name (str): The name of the metric (e.g., 'Average Recovery')
        data_dict (dict): Dictionary containing the data for this metric (MUST contain keys from models_list)
        models_list (list): List of model keys to plot from data_dict
        legend_names_list(list): List of names for the legend (MUST match models_list order)
        ranges_list (list): List of sequence length range names
    """
    n_models = len(models_list) # Now n_models will be 7
    n_ranges = len(ranges_list)

    x = np.arange(n_ranges)
    total_width = 0.8 # Keep total width allocation
    width = total_width / n_models # Bar width adjusts automatically based on n_models
    offsets = np.linspace(-total_width / 2 + width / 2, total_width / 2 - width / 2, n_models)

    fig, ax = plt.subplots(figsize=(14, 7), layout='constrained')

    for i, model_key in enumerate(models_list):
        # Check if model exists in data_dict before trying to access it
        if model_key in data_dict:
             model_data = data_dict[model_key]
        else:
            print(f"Warning: Model key '{model_key}' not found in data for metric '{metric_name}'. Skipping.")
            continue # Skip plotting if data is missing

        legend_name = legend_names_list[i]
        offset = offsets[i]
        rects = ax.bar(x + offset, model_data, width, label=legend_name)

        # Add horizontal value labels above bars
        labels = [f"{height:.3f}" for height in model_data]
        ax.bar_label(rects,
                     labels=labels,
                     padding=3,
                     fontsize=9,
                     fontweight='bold',
                     rotation=0)

    # Add labels and title
    ax.set_ylabel(metric_name.split()[-1])
    ax.set_title(f'{metric_name} Comparison Across Sequence Lengths')
    ax.set_xticks(x)
    ax.set_xticklabels(ranges_list)

    # Place legend inside using 'best' location, large font
    ax.legend(loc='best', fontsize='large')

    # Adjust Y-axis limits
    # Calculate limits based only on the models actually plotted
    all_values = [val for model_key in models_list if model_key in data_dict for val in data_dict[model_key] ]
    if not all_values:
        print(f"Warning: No data found to plot for metric '{metric_name}'. Y-axis limits may be incorrect.")
        min_val, max_val = 0, 1
    else:
        min_val = min(all_values)
        max_val = max(all_values)

    padding_bottom = (max_val - min_val) * 0.05 if max_val > min_val else 0.05
    padding_top = (max_val - min_val) * 0.15 if max_val > min_val else 0.15
    ax.set_ylim([min_val - padding_bottom, max_val + padding_top])

    # Add grid lines
    ax.yaxis.grid(True, linestyle='--', alpha=0.7)

    # Save the figure to the current directory
    # Create a filename based on the metric name
    filename = f"{metric_name.replace(' ', '_')}_comparison_new_data.png"
    fig.savefig(filename, dpi=300, bbox_inches='tight')
    print(f"Saved plot to: {filename}")

    plt.show()

# --- Generate the TWO plots for which data is available ---
try:
    plot_metric_comparison('Average Recovery', data['Average Recovery'], models, legend_names, ranges)
except KeyError as e:
    print(f"Error plotting Average Recovery: Missing key {e}")

try:
    plot_metric_comparison('Average SC Score', data['Average SC Score'], models, legend_names, ranges)
except KeyError as e:
    print(f"Error plotting Average SC Score: Missing key {e}")

# Removed plotting calls for 'Median Recovery' and 'Median SC Score'
